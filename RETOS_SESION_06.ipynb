# %% [markdown]
# Tenemos un diccionario que contiene los gastos mensuales de distintas divisiones de una empresa. Cada división está identificada por un nombre y su gasto mensual.
#
# datos = {
#     "Marketing": 32000,
#     "Ventas": 45000,
#     "Desarrollo de Producto": 62000,
#     "Soporte Técnico": 25000,
#     "Recursos Humanos": 15000,
#     "IT": 50000,
#     "Operaciones": 47000,
#     "Investigación y Desarrollo": 55000
# }
# Realiza los siguientes pasos para explorar y manipular los datos:
#
# 📊 Crea una serie de pandas a partir del diccionario datos y llámala gastos_mensuales.
#
# 🧐 Imprime la siguiente información de la serie gastos_mensuales:
#
# 🔢 Tamaño de la serie para verificar cuántas divisiones hay.
# 📏 Tipo de dato de la serie para asegurarte de que todos los datos son numéricos.
# 🏷️ Divisiones incluidas en la serie.
# 🔍 Usando diferentes métodos de indexación obtén la siguiente información:
#
# 💼 Gastos de Ventas, IT e Investigación y Desarrollo.
# 📈 Gastos desde Marketing hasta Recursos Humanos.
# 🛠️ Gastos desde Desarrollo de Producto hasta Operaciones.
# 🚀 Gastos desde Soporte Técnico hasta la última división.

# %%
import pandas as pd

# %%
datos = {
    "Marketing": 32000,
    "Ventas": 45000,
    "Desarrollo de Producto": 62000,
    "Soporte Técnico": 25000,
    "Recursos Humanos": 15000,
    "IT": 50000,
    "Operaciones": 47000,
    "Investigación y Desarrollo": 55000
}

# Crea una serie de pandas a partir del diccionario datos y llámala gastos_mensuales.

gastos_mensuales = pd.Series(datos)
gastos_mensuales

#Tamaño de la serie para verificar cuántas divisiones hay.

gastos_mensuales.size

#📏 Tipo de dato de la serie para asegurarte de que todos los datos son numéricos.

gastos_mensuales.dtype

# 🏷️ Divisiones incluidas en la serie.

gastos_mensuales.index

# Usando diferentes métodos de indexación obtén la siguiente información:

# 💼 Gastos de Ventas, IT e Investigación y Desarrollo.
# 📈 Gastos desde Marketing hasta Recursos Humanos.
# 🛠️ Gastos desde Desarrollo de Producto hasta Operaciones.
# 🚀 Gastos desde Soporte Técnico hasta la última división.

gastos_mensuales[["Ventas", "IT", "Investigación y Desarrollo"]]

gastos_mensuales[:"Recursos Humanos"]

gastos_mensuales["Desarrollo de Producto":]

gastos_mensuales["Soporte Técnico":]
# Out:
# Soporte Técnico               25000
# Recursos Humanos              15000
# IT                            50000
# Operaciones                   47000
# Investigación y Desarrollo    55000
# dtype: int64

# %% [markdown]
# Reto 2
#
# Considera el siguiente conjunto de datos que representa varios proyectos en una empresa de software. Cada proyecto tiene:
#
# Un nombre único.
# Una fase actual.
# Un costo estimado.
# Una duración estimada en días.
# import pandas as pd
#
# # Datos de proyectos
# datos = {
#     'Fase Actual': ['Diseño', 'Desarrollo', 'Testing', 'Lanzamiento', 'Mantenimiento'],
#     'Costo Estimado': [20000, 50000, 15000, 30000, 10000],
#     'Duración Estimada': [30, 90, 15, 20, 60]  # Duración en días
# }
# Realiza los siguientes pasos para gestionar y analizar los datos de proyectos:
#
# 📊 Crear el dataframe con índices personalizados:
#
# Utiliza cualquier nombre para los 5 proyectos como índices.
# Imprime el dataframe inicial.
# 📊 Añade una nueva columna al dataframe llamada 'Riesgo de Retraso': que evalúe la duración estimada de cada proyecto. Si la duración es superior a 50 días, asigna un riesgo de "Alto", de lo contrario, será "Bajo".
#
# Puedes utilizar un list comprehension para evaluar cada fila del DataFrame y asignar el riesgo correspondiente.
#
# ['Alto' if x > 50 else 'Bajo' for x in proyectos['Duración Estimada']]
# 🔄 Actualiza la columna 'Costo Estimado': con nuevos valores basados en revisiones recientes del presupuesto.
#
# ❌ Elimina la columna 'Duración Estimada': del DataFrame.

# %%
datos = {
    'Fase Actual': ['Diseño', 'Desarrollo', 'Testing', 'Lanzamiento', 'Mantenimiento'],
    'Costo Estimado': [20000, 50000, 15000, 30000, 10000],
    'Duración Estimada': [30, 90, 15, 20, 60]  # Duración en días
}

print(datos)

print("______________")
# Crear el dataframe con índices personalizados:

proyectos = pd.DataFrame(datos, index = ['Proyecto A', 'Proyecto B', 'Proyecto C', 'Proyecto D', 'Proyecto E'])
proyectos
print(proyectos)

print("______________")

# Añadir columna "Riesgo de Retraso

proyectos['Riesgo de Retraso'] = ['Alto' if x > 50 else 'Bajo' for x in proyectos['Duración Estimada']]
proyectos

print("______________")


# Actualiza la columna 'Costo Estimado': con nuevos valores basados en revisiones recientes del presupuesto.

proyectos['Costo Estimado'] = [25000, 60000, 20000, 40000, 15000]
print(proyectos)

print("______________")

# Elimina la columna 'Duración Estimada': del DataFrame.

proyectos = proyectos.drop(columns=["Duración Estimada"])
print(proyectos)
# Out:
# {'Fase Actual': ['Diseño', 'Desarrollo', 'Testing', 'Lanzamiento', 'Mantenimiento'], 'Costo Estimado': [20000, 50000, 15000, 30000, 10000], 'Duración Estimada': [30, 90, 15, 20, 60]}
# ______________
#               Fase Actual  Costo Estimado  Duración Estimada
# Proyecto A         Diseño           20000                 30
# Proyecto B     Desarrollo           50000                 90
# Proyecto C        Testing           15000                 15
# Proyecto D    Lanzamiento           30000                 20
# Proyecto E  Mantenimiento           10000                 60
# ______________
# ______________
#               Fase Actual  Costo Estimado  Duración Estimada Riesgo de Retraso
# Proyecto A         Diseño           25000                 30              Bajo
# Proyecto B     Desarrollo           60000                 90              Alto
# Proyecto C        Testing           20000                 15              Bajo
# ...

# %% [markdown]
# Imagina que trabajas en una empresa de bienes raíces y te han asignado la tarea de analizar un conjunto de datos sobre los precios de viviendas para identificar tendencias y patrones que puedan influir en las estrategias de venta y marketing. Este análisis te permitirá proporcionar recomendaciones basadas en datos para mejorar la toma de decisiones en la empresa. Tu jefe te ha solicitado un informe detallado con tus conclusiones individuales, destacando los hallazgos más relevantes.
#
# Acciones que el programa debe realizar:
#
# Cargar un conjunto de datos de precios de viviendas desde un archivo CSV.
# Realizar una limpieza básica de los datos, eliminando duplicados y manejando valores faltantes.
# Crear series a partir de las columnas del DataFrame y calcular estadísticas básicas como la media y la mediana.
# Utilizar métodos avanzados de indexación para filtrar y seleccionar subconjuntos específicos de datos.
# Añadir y modificar columnas en el DataFrame para incluir cálculos adicionales, como el precio por metro cuadrado.
# Para ello, el programa debe seguir estos pasos:
#
# Cargar y limpiar datos. Utiliza Pandas para cargar los datos desde el archivo CSV proporcionado. Realiza una limpieza básica para asegurar la calidad de los datos.
# Crear y analizar series. Extrae y analiza las series de interés, calculando estadísticas básicas que sean relevantes para el análisis.
# Filtrar y seleccionar datos. Aplica métodos avanzados de indexación para filtrar y seleccionar subconjuntos de datos que cumplan con ciertos criterios en específico.
# Añadir y modificar columnas. Crea nuevas columnas para realizar cálculos adicionales que proporcionen mayor detalle y contexto al análisis.
# Redacción del informe. Redacta un informe detallado con tus conclusiones individuales, destacando los hallazgos más relevantes y cómo pueden influir en las decisiones estratégicas de la empresa

# %%
import pandas as pd

# %%
df_csv = pd.read_csv('/content/sample_data/california_housing_train.csv')
df_csv.head()
# Out:
#    longitude  latitude  housing_median_age  total_rooms  total_bedrooms  \
# 0    -114.31     34.19                15.0       5612.0          1283.0
# 1    -114.47     34.40                19.0       7650.0          1901.0
# 2    -114.56     33.69                17.0        720.0           174.0
# 3    -114.57     33.64                14.0       1501.0           337.0
# 4    -114.57     33.57                20.0       1454.0           326.0
#
#    population  households  median_income  median_house_value
# 0      1015.0       472.0         1.4936             66900.0
# 1      1129.0       463.0         1.8200             80100.0
# 2       333.0       117.0         1.6509             85700.0
# 3       515.0       226.0         3.1917             73400.0
# 4       624.0       262.0         1.9250             65500.0

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
df_excel = pd.read_excel('/content/drive/MyDrive/Newbedu/Casas usadas - RM Mayo 2020.xlsx')
df_excel.head()
# Out:
#             Comuna                                               Link  \
# 0  Calera de Tango  https://chilepropiedades.cl/ver-publicacion/ve...
# 1  Calera de Tango  https://chilepropiedades.cl/ver-publicacion/ve...
# 2  Calera de Tango  https://chilepropiedades.cl/ver-publicacion/ve...
# 3  Calera de Tango  https://chilepropiedades.cl/ver-publicacion/ve...
# 4  Calera de Tango  https://chilepropiedades.cl/ver-publicacion/ve...
#
#   Tipo_Vivienda  N_Habitaciones  N_Baños N_Estacionamientos  \
# 0          Casa             5.0      6.0                  3
# 1          Casa             6.0      6.0                  6
# 2          Casa             3.0      3.0                 No
# 3          Casa             8.0      6.0                 No
# 4          Casa             3.0      2.0                  3
#
#    Total_Superficie_M2 Superficie_Construida_M2  Valor_UF  Valor_CLP  \
# 0               5000.0                      440   12200.0  351360000
# ...

# %%
df_excel.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1139 entries, 0 to 1138
# Data columns (total 13 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   Comuna                    1139 non-null   object
#  1   Link                      1139 non-null   object
#  2   Tipo_Vivienda             1139 non-null   object
#  3   N_Habitaciones            1131 non-null   float64
#  4   N_Baños                   1118 non-null   float64
#  5   N_Estacionamientos        1067 non-null   object
#  6   Total_Superficie_M2       1102 non-null   float64
#  7   Superficie_Construida_M2  1103 non-null   object
#  8   Valor_UF                  1139 non-null   float64
#  9   Valor_CLP                 1139 non-null   int64
#  10  Dirección                 1102 non-null   object
#  11  Quién_Vende               1139 non-null   object
#  12  Corredor                  1139 non-null   object
# dtypes: float64(4), int64(1), object(8)
# ...

# %%
# LIMPIEZA DE DATOS

# Eliminar duplicados
df = df_excel.drop_duplicates()

# Dejar sólo valores NO Nulos
df = df_excel.dropna()

# CREAR Y ANALIZAR SERIES
Valor_CLP = df["Valor_CLP"]  # Precio en Pesos Chilenos
Total_Superficie_M2 = df["Total_Superficie_M2"]  # Metros_cuadrados

# Cálculo de estadísticas básicas
media_precio = Valor_CLP.mean()
mediana_precio = Valor_CLP.median()
print(f"Media del precio: {media_precio}")
print(f"Mediana del precio: {mediana_precio}")
media_superficie = Total_Superficie_M2.mean()
mediana_superficie = Total_Superficie_M2.median()
print(f"Media de la superficie: {media_superficie}")
print(f"Mediana de la superficie: {mediana_superficie}")
viviendas_caras = Valor_CLP > media_precio
viviendas_caras = df[viviendas_caras]
print(viviendas_caras)

print('____________________________________________________________')

# AÑADIR Y MODIFICAR COLUMNAS
# Agregar una nueva columna con el precio por metro cuadrado
df["precio_por_m2"] = df["Valor_CLP"] / df["Total_Superficie_M2"]

# Calcular la mediana del precio por metro cuadrado
mediana_precio_por_m2 = df["precio_por_m2"].median()
print(f"Mediana del precio por metro cuadrado: {mediana_precio_por_m2}")
print(df.head())

# GENERAR INFORME DE HALLAZGOS
informe = f"""
Análisis de precios de viviendas:
- Media de los precios: {media_precio}
- Mediana de los precios: {mediana_precio}
- Total de viviendas analizadas: {len(df)}
- Viviendas con precios superiores a la media: {len(viviendas_caras)}
"""
print(informe)
# Out:
# Media del precio: 309424573.22718054
# Mediana del precio: 210240000.0
# Media de la superficie: 884.9565922920892
# Mediana de la superficie: 300.0
#                Comuna                                               Link  \
# 0     Calera de Tango  https://chilepropiedades.cl/ver-publicacion/ve...
# 1     Calera de Tango  https://chilepropiedades.cl/ver-publicacion/ve...
# 3     Calera de Tango  https://chilepropiedades.cl/ver-publicacion/ve...
# 5     Calera de Tango  https://chilepropiedades.cl/ver-publicacion/ve...
# 7     Calera de Tango  https://chilepropiedades.cl/ver-publicacion/ve...
# ...               ...                                                ...
# 1134         Vitacura  https://chilepropiedades.cl/ver-publicacion/ve...
# 1135         Vitacura  https://chilepropiedades.cl/ver-publicacion/ve...
# 1136         Vitacura  https://chilepropiedades.cl/ver-publicacion/ve...
# 1137         Vitacura  https://chilepropiedades.cl/ver-publicacion/ve...
# ...
